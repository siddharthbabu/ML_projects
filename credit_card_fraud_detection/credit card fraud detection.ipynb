# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#check null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#description of data
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
#classes
df['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#number of cases
print('fraud cases :', len(df[df['Class']==1]))
print('non fraud cases :', len(df[df['Class']==0]))
# Out:
# fraud cases : 492
# non fraud cases : 284315

# %%
fraud = df[df['Class']==1]
genuine = df[df['Class']==0]

# %%
rcParams['figure.figsize'] = 16, 8
f,(ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')
ax1.scatter(fraud.Time, fraud.Amount)
ax1.set_title('Fraud')
ax2.scatter(genuine.Time, genuine.Amount)
ax2.set_title('Genuine')
plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
#splitting the data
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score,classification_report

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
print(X.shape)
print(y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
#models used
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Model 1

# %%
#Random forest classifier
rfc = RandomForestClassifier()
model = rfc.fit(X_train, y_train)
rfc_pred = model.predict(X_test)

# %%
print("For Random Forest classifier") 
  
acc = accuracy_score(y_test, rfc_pred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(y_test, rfc_pred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(y_test, rfc_pred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(y_test, rfc_pred) 
print("The F1-Score is {}".format(f1)) 
print("\nClassification Report:",classification_report(y_test, rfc_pred))
# Out:
# For Random Forest classifier
# The accuracy is 0.9996137776061234
# The precision is 0.9401709401709402
# The recall is 0.8088235294117647
# The F1-Score is 0.8695652173913043
#
# Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.94      0.81      0.87       136
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.90      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### Model 2

# %%
#Logistic regression
lr = LogisticRegression()
model_2 = lr.fit(X_train, y_train)
lr_pred = model_2.predict(X_test)

# %%
print("For Random Forest classifier") 
  
acc = accuracy_score(y_test, lr_pred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(y_test, lr_pred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(y_test, lr_pred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(y_test, lr_pred) 
print("The F1-Score is {}".format(f1)) 

print("\nClassification Report:",classification_report(y_test, lr_pred))
# Out:
# For Random Forest classifier
# The accuracy is 0.9988530365272755
# The precision is 0.6484375
# The recall is 0.6102941176470589
# The F1-Score is 0.6287878787878788
#
# Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.65      0.61      0.63       136
#
#     accuracy                           1.00     85443
#    macro avg       0.82      0.80      0.81     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### Model 3

# %%
#Decision tree
dc = DecisionTreeClassifier()
model_3 = dc.fit(X_train, y_train)
dc_pred = model_3.predict(X_test)

# %%
print("For Random Forest classifier") 
  
acc = accuracy_score(y_test, dc_pred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(y_test, dc_pred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(y_test, dc_pred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(y_test, dc_pred) 
print("The F1-Score is {}".format(f1)) 
print("\nClassification Report:",classification_report(y_test, dc_pred))
# Out:
# For Random Forest classifier
# The accuracy is 0.9991105181231933
# The precision is 0.7027027027027027
# The recall is 0.7647058823529411
# The F1-Score is 0.7323943661971832
#
# Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.70      0.76      0.73       136
#
#     accuracy                           1.00     85443
#    macro avg       0.85      0.88      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Looking at the classification reports we can conclude that:
# Precision: Report 1 has the highest precision for class 1, indicating that it has the highest proportion of correct positive predictions among all positive predictions. This is important if minimizing false positives is a priority.
#
# Recall: Report 3 has the highest recall for class 1, indicating that it has the highest proportion of correctly predicted positive instances out of all actual positive instances. This is important if capturing all positive instances is a priority.
#
# F1-score: The F1-score is the harmonic mean of precision and recall, so it provides a balance between the two metrics. Report 1 has the highest F1-score for class 1, indicating a balance between precision and recall.
#
# Accuracy: All reports have the same overall accuracy, but accuracy alone may not be the best metric for imbalanced datasets like fraud detection, where the number of non-fraudulent transactions far exceeds the number of fraudulent transactions.
#
# In conclusion, Report 1 may be preferred due to its high precision. If the goal is to capture as many fraudulent transactions as possible, Report 3 may be preferred due to its high recall.
